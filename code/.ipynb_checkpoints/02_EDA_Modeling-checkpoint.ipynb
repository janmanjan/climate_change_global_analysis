# %%
# Imports
import pandas as pd
import numpy as np
from scipy.stats import zscore
from scipy.cluster.hierarchy import dendrogram, linkage, cophenet
from scipy.spatial.distance import cdist, pdist

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler, LabelEncoder

from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer

# %matplotlib inline

# %%
# reading in final dataframe
df = pd.read_csv('../data/cleaned_data/kahuna.csv')

# %%
def histogram_boxplot(data, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to the show density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %% [markdown]
# -------------------------

# %% [markdown]
# ## KMeans Clustering

# %%
X = df.drop(columns=['Entity', 'Year'])
sc = StandardScaler()
X_sc = sc.fit_transform(X)

# %%
km = KMeans(n_clusters=4, random_state=42)
km.fit(X_sc)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
km.cluster_centers_;

# %%
df['cluster'] = km.labels_
df.head()
# Out:
#     Entity  Year   Deaths %  CO2 Emissions  CO2 Emissions Per Cap
# 0  Albania  1991  17.613636        4228256                 1.2889
# 1  Albania  1995  16.789055        2066496                 0.6638
# 2  Albania  1996  16.588451        1993216                 0.6432
# 3  Albania  1997  15.081361        1531552                 0.4941
# 4  Albania  1998  15.965796        1744064                 0.5607
#
#    Food Emissions  Total GHG  Consumption of Ozone  Shared CO2 Emissions
# 0       4011691.0  9030000.0                   0.0                  0.02
# 1       4861321.1  7480000.0                  43.4                  0.01
# 2       4569702.9  7280000.0                  43.2                  0.01
# 3       4431656.7  6510000.0                  45.2                  0.01
# 4       4344061.6  6810000.0                  49.6                  0.01
#
#    Transport  ...  Death_5-14  Death_50-69   Death_70+  Death_15-49  Urban%
# 0   500000.0  ...    5.975427   271.661092  512.126572    60.714220  36.700
# 1   600000.0  ...    4.580403   240.740486  469.406670    49.692924  38.911
# 2   600000.0  ...    4.373679   255.560407  491.357876    52.069689  39.473
# 3   500000.0  ...    4.414006   269.448518  521.197486    57.988035  40.035
# 4   700000.0  ...    4.493629   280.472022  547.315668    64.973478  40.601
#
#    Child Mortality  Population          GDP  Forest area  cluster
# 0             3.93  119.225912  3496.580246     786850.0        0
# 1             3.39  116.342482  4471.871070     779050.0        0
# 2             3.26  115.621642  4909.228105     777100.0        0
# 3             3.13  114.900766  4400.577827     775150.0        0
# 4             2.99  114.179927  4819.387534     773200.0        0
#
# [5 rows x 27 columns]

# %%
# comparision of numerical representations of clusters means
df.groupby('cluster').mean().T
# Out:
# cluster                                  0             1             2  \
# Year                          2.002649e+03  2.001500e+03  2.001500e+03
# Deaths %                      8.892321e+00  3.911636e+00  1.983135e+01
# CO2 Emissions                 1.424533e+08  5.664404e+09  3.149207e+09
# CO2 Emissions Per Cap         7.425649e+00  1.994650e+01  2.463833e+00
# Food Emissions                9.403939e+07  1.411459e+09  1.432680e+09
# Total GHG                     2.211048e+08  6.159870e+09  3.915459e+09
# Consumption of Ozone          1.531404e+03  4.746796e+04  3.551738e+04
# Shared CO2 Emissions          5.124244e-01  2.097917e+01  1.093333e+01
# Transport                     2.748302e+07  1.637742e+09  2.191417e+08
# Death_rate_ambient_ozone_pol  1.770424e+00  3.014308e+00  1.621379e+01
# Death_rate_household_air_pol  1.692004e+01  7.250909e-02  1.321593e+02
# Death_rate_all_causes         6.232674e+01  2.098069e+01  8.002124e+01
# Death_actual_ozone            3.387334e+02  1.260691e+04  1.027083e+05
# Death_actual_particulate      1.120365e+04  8.076044e+04  6.560596e+05
# Death_actual_household        3.018900e+03  2.773371e+02  9.306099e+05
# Death_under5                  6.185610e+02  9.641439e+02  6.091231e+04
# Death_5-14                    2.026369e+01  7.433022e+00  1.765129e+03
# Death_50-69                   4.018251e+03  2.605672e+04  2.280127e+05
# Death_70+                     5.755474e+03  6.142555e+04  4.119236e+05
# Death_15-49                   1.129838e+03  4.913515e+03  5.615419e+04
# Urban%                        6.916468e+01  7.887479e+01  3.354469e+01
# Child Mortality               2.216006e+00  8.579167e-01  5.998958e+00
# Population                    2.120173e+02  3.112386e+01  2.490085e+02
# GDP                           2.197846e+04  4.930289e+04  3.911556e+03
# Forest area                   3.660463e+07  3.051919e+08  1.243952e+08
# clusterx10                    1.427010e+00  4.000000e+00  5.041667e+00
#
# cluster                                  3
# Year                          2.001426e+03
# Deaths %                      1.428452e+01
# CO2 Emissions                 2.418201e+07
# CO2 Emissions Per Cap         6.830963e-01
# Food Emissions                1.208070e+08
# Total GHG                     1.444425e+08
# Consumption of Ozone          5.026049e+02
# Shared CO2 Emissions          8.928389e-02
# Transport                     6.018926e+06
# Death_rate_ambient_ozone_pol  3.367290e+00
# Death_rate_household_air_pol  1.530417e+02
# Death_rate_all_causes         4.165425e+01
# Death_actual_ozone            6.524107e+02
# Death_actual_particulate      9.445955e+03
# Death_actual_household        3.479563e+04
# Death_under5                  2.704770e+03
# Death_5-14                    6.206465e+01
# Death_50-69                   2.893413e+03
# Death_70+                     3.457955e+03
# Death_15-49                   9.801622e+02
# Urban%                        3.599857e+01
# Child Mortality               8.961726e+00
# Population                    1.188908e+02
# GDP                           3.534934e+03
# Forest area                   1.981331e+07
# clusterx10                    2.194373e+00

# %%
columns = df.columns.drop(['Entity', 'cluster', 'Year'])

# %%
km.cluster_centers_;

# %%
df.shape
# Out:
# (2409, 28)

# %%
centroids = pd.DataFrame(
    sc.inverse_transform(km.cluster_centers_),
    columns=columns
)
centroids
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19260/477277247.py in <module>
# ----> 1 centroids = pd.DataFrame(
#       2     sc.inverse_transform(km.cluster_centers_),
#       3     columns=columns
#       4 )
#       5 centroids
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     670                 )
#     671             else:
# --> 672                 mgr = ndarray_to_mgr(
#     673                     data,
#     674                     index,
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     322     )
#     323
# --> 324     _check_values_indices_shape_match(values, index, columns)
#     325
#     326     if typ == "array":
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _check_values_indices_shape_match(values, index, columns)
#     391         passed = values.shape
#     392         implied = (len(index), len(columns))
# --> 393         raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#     394
#     395
#
# ValueError: Shape of passed values is (4, 26), indices imply (4, 25)

# %%
scores = []
for k in range(2, 31):
    cl = KMeans(n_clusters=k)
    cl.fit(X_sc)
    inertia = cl.inertia_
    sil = silhouette_score(X_sc, cl.labels_)
    scores.append([k, inertia, sil])
    
score_df = pd.DataFrame(scores)
score_df.columns = ['k', 'inertia', 'silhouette']

# %%
score_df.head(11)
# Out:
#      k       inertia  silhouette
# 0    2  38563.314328    0.798139
# 1    3  32001.744490    0.761287
# 2    4  25712.987016    0.276625
# 3    5  22522.346493    0.279479
# 4    6  19666.013103    0.300375
# 5    7  17100.063160    0.340825
# 6    8  15032.365919    0.353031
# 7    9  12996.814866    0.309837
# 8   10  11713.346233    0.323118
# 9   11  10628.003387    0.326535
# 10  12   9845.774864    0.278287

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 7))
axes[0].plot(score_df.k, score_df.inertia)
axes[0].set_title('Inertia over k')
axes[1].plot(score_df.k, score_df.silhouette);
axes[1].set_title('Silhouette Score over k');

# %%
# group is the largest cluster by far
df['cluster'].value_counts()
# Out:
# 0    2337
# 1      48
# 2      24
# Name: cluster, dtype: int64

# %%
km_10 = KMeans(n_clusters=10, random_state=42)
km_10.fit(X_sc)
# Out:
# KMeans(n_clusters=10, random_state=42)

# %%
df['clusterx10'] = km_10.labels_

# %%
df['clusterx10'].value_counts()
# Out:
# 8    1167
# 3     561
# 0     398
# 4     121
# 6      66
# 1      24
# 9      24
# 2      24
# 5      14
# 7      10
# Name: clusterx10, dtype: int64

# %%
df.groupby(by='clusterx10').mean().T.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df['Entity'].value_counts()
# Out:
# Ecuador      25
# Pakistan     25
# Togo         25
# Egypt        25
# Brazil       25
#              ..
# Lithuania     9
# Sweden        5
# Finland       5
# Austria       5
# Sudan         2
# Name: Entity, Length: 116, dtype: int64

# %%
df.groupby('cluster').mean().T.plot(kind='barh')
plt.figure(figsize=(40,20))

# %%
lis = [1,2,3,4,4]
lis.reverse()
lis
# Out:
# [4, 4, 3, 2, 1]

# %%
rev_columns = list(columns.astype(str))
rev_columns.reverse()

# %%
china = df[df['Entity'] == 'China']

# %%
plt.bar(china['Year'], china['Deaths %'])
plt.xlabel('Year')
plt.ylabel('Death %')
plt.title('China: Death % over Time')
# Out:
# Text(0.5, 1.0, 'China: Death % over Time')

# %%
plt.scatter(china['Year'], china['Deaths %'])
plt.xlabel('Year')
plt.ylabel('Death %')
plt.title('China: Death % over Time')
# Out:
# Text(0.5, 1.0, 'China: Death % over Time')

# %%
colors = ["red", "green", "blue"]
china['color'] = china['cluster'].map(lambda p: colors[p])

ax = china.plot(    
    kind="scatter", 
    x='Deaths %', y='CO2 Emissions',
    figsize=(10,8),
    c = china['color']
)
centroids.plot(
kind="scatter", 
x='Deaths %', y='CO2 Emissions', 
marker="*", c=["maroon", "darkgreen", "navy"], s=550,
ax=ax);
# Out:
# C:\Users\saraz\AppData\Local\Temp/ipykernel_14484/1607540067.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   china['color'] = china['cluster'].map(lambda p: colors[p])

# %%
for x, y in zip(columns, rev_columns):
    colors = ["red", "green", "blue"]
    df['color'] = df['cluster'].map(lambda p: colors[p])

    ax = df.plot(    
        kind="scatter", 
        x=x, y=y,
        figsize=(10,8),
        c = df['color']
    )
    centroids.plot(
    kind="scatter", 
    x=x, y=y, 
    marker="*", c=["maroon", "darkgreen", "navy"], s=550,
    ax=ax
    );
# Out:
# C:\Users\saraz\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:345: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %% [markdown]
# ###

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(df.corr(), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral")
plt.show()

# %%
le = LabelEncoder()
df['Entity'] = le.fit_transform(df['Entity'])
scaler = StandardScaler()
subset = df.copy()
subset.color = subset.color.map({'red':1, 'green':2, 'blue':3})
subset_scaled = scaler.fit_transform(subset)
subset_scaled_df = pd.DataFrame(subset_scaled, columns=subset.columns)
k_means_df = subset_scaled_df.copy()

# %%
model = KMeans(random_state=1)
visualizer = KElbowVisualizer(model, k=(2, 30), metric="silhouette", timings=True)
visualizer.fit(k_means_df)  # fit the data to the visualizer
visualizer.show()  # finalize and render figure
# Out:
# <AxesSubplot:title={'center':'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>

# %%
sil_score = []
cluster_list = range(2, 10)
for n_clusters in cluster_list:
    clusterer = KMeans(n_clusters=n_clusters, random_state=1)
    preds = clusterer.fit_predict((subset_scaled_df))
    score = silhouette_score(k_means_df, preds)
    sil_score.append(score)
    print("For n_clusters = {}, the silhouette score is {})".format(n_clusters, score))
# Out:
# For n_clusters = 2, the silhouette score is 0.7698811755052991)
# For n_clusters = 3, the silhouette score is 0.7667084498893547)
# For n_clusters = 4, the silhouette score is 0.2348744961835416)
# For n_clusters = 5, the silhouette score is 0.26427054041673415)
# For n_clusters = 6, the silhouette score is 0.26672919476855983)
# For n_clusters = 7, the silhouette score is 0.2892008851550342)
# For n_clusters = 8, the silhouette score is 0.3117119980809646)
# For n_clusters = 9, the silhouette score is 0.3276035608149105)

# %%
# finding optimal no. of clusters with silhouette coefficients
visualizer = SilhouetteVisualizer(KMeans(5, random_state=1))
visualizer.fit(k_means_df)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 2409 Samples in 5 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
# finding optimal no. of clusters with silhouette coefficients
visualizer = SilhouetteVisualizer(KMeans(4, random_state=1))
visualizer.fit(k_means_df)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 2409 Samples in 4 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
# finding optimal no. of clusters with silhouette coefficients
visualizer = SilhouetteVisualizer(KMeans(3, random_state=1))
visualizer.fit(k_means_df)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 2409 Samples in 3 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
# finding optimal no. of clusters with silhouette coefficients
visualizer = SilhouetteVisualizer(KMeans(2, random_state=1))
visualizer.fit(k_means_df)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 2409 Samples in 2 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %% [markdown]
# **Observations**
#
# - The silhouette coefficient for 3 clusters is the highest.
# - We can also see that the score for 3 clusters is close to the average score and the shape of the clusters is very uniform in SilhouetteVisualizer, even though the magnitude may be different.
# - So, we will proceed with 3 clusters.

# %% [markdown]
# ## Hierarchical Clustering

# %%
df.color = df.color.map({'red':1, 'green':2, 'blue':3})

# %%
ss = StandardScaler()
df_sc = ss.fit_transform(df)

model = AgglomerativeClustering(distance_threshold=100, affinity='euclidean',  linkage='average', n_clusters =None)
model.fit(df_sc)
df['labels'] = model.labels_
df_clust = df.groupby(['labels'])

# %%
Z = linkage(df_sc, metric='euclidean', method='average')
c, coph_dists = cophenet(Z , pdist(df_sc))

# %%
# %%time
plt.figure(figsize=(25, 5))
plt.title('Agglomerative Hierarchical Clustering Dendogram')
plt.xlabel('sample index')
plt.ylabel('Distance')
dendrogram(Z, leaf_rotation=90.,color_threshold = 40, truncate_mode ='level' ,leaf_font_size=8. )
plt.tight_layout()
# Out:
# Wall time: 8.12 s
